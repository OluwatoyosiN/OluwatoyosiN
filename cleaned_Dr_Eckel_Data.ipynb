# %% [markdown]
# <a href="https://colab.research.google.com/github/OluwatoyosiN/OluwatoyosiN/blob/main/cleaned_Dr_Eckel_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-3f4997ce-d68b-4e90-8ace-a31932902095" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f4997ce-d68b-4e90-8ace-a31932902095">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving carbon_data.xlsx to carbon_data.xlsx

# %%
import io
both1= pd.read_excel(io.BytesIO(uploaded[ "carbon_data.xlsx"]))
both1
# Out:
#       Unnamed: 0 Booking_date Order_number  \
# 0              0   2022-07-20  VKAU-102380
# 1              1   2022-07-21  VKAU-102382
# 2              2   2022-07-18  VKAU-102379
# 3              3   2022-07-18  VKAU-102378
# 4              4   2022-07-15  VKAU-102377
# ...          ...          ...          ...
# 2369        2369   2020-04-07  VKAU-100005
# 2370        2370   2020-04-17  VKAU-100004
# 2371        2371   2020-04-30  VKAU-100003
# 2372        2372   2020-04-27  VKAU-100002
# 2373        2373   2020-04-29  VKAU-100001
#
#                               Customer_name Customer_postal_code  \
# 0                  Möhlenkamp GmbH & Co. KG                26901
# 1     Spezialfutter Neuruppin GmbH & Co. KG                16816
# 2                               Hoogland BV              8903 JN
# 3                                Tromp B.V.              8912 AT
# 4                        Xaver Scheule GmbH                87757
# ...

# %%
both1.drop(["Delivery_Country","Delivery_Postal_Code2","Outgoing_goods_date","Outgoing_goods_date","Customer_Delivery_address_name"],axis=1, inplace=True)

# %%
both1
# Out:
#       Unnamed: 0 Booking_date Order_number  \
# 0              0   2022-07-20  VKAU-102380
# 1              1   2022-07-21  VKAU-102382
# 2              2   2022-07-18  VKAU-102379
# 3              3   2022-07-18  VKAU-102378
# 4              4   2022-07-15  VKAU-102377
# ...          ...          ...          ...
# 2369        2369   2020-04-07  VKAU-100005
# 2370        2370   2020-04-17  VKAU-100004
# 2371        2371   2020-04-30  VKAU-100003
# 2372        2372   2020-04-27  VKAU-100002
# 2373        2373   2020-04-29  VKAU-100001
#
#                               Customer_name Customer_postal_code  \
# 0                  Möhlenkamp GmbH & Co. KG                26901
# 1     Spezialfutter Neuruppin GmbH & Co. KG                16816
# 2                               Hoogland BV              8903 JN
# 3                                Tromp B.V.              8912 AT
# 4                        Xaver Scheule GmbH                87757
# ...

# %%
both1["Pickup station"]= "Im Stiefelfeld 10, 56651 Neiderzissen, Germany"
both1
# Out:
#       Unnamed: 0 Booking_date Order_number  \
# 0              0   2022-07-20  VKAU-102380
# 1              1   2022-07-21  VKAU-102382
# 2              2   2022-07-18  VKAU-102379
# 3              3   2022-07-18  VKAU-102378
# 4              4   2022-07-15  VKAU-102377
# ...          ...          ...          ...
# 2369        2369   2020-04-07  VKAU-100005
# 2370        2370   2020-04-17  VKAU-100004
# 2371        2371   2020-04-30  VKAU-100003
# 2372        2372   2020-04-27  VKAU-100002
# 2373        2373   2020-04-29  VKAU-100001
#
#                               Customer_name Customer_postal_code  \
# 0                  Möhlenkamp GmbH & Co. KG                26901
# 1     Spezialfutter Neuruppin GmbH & Co. KG                16816
# 2                               Hoogland BV              8903 JN
# 3                                Tromp B.V.              8912 AT
# 4                        Xaver Scheule GmbH                87757
# ...

# %%
pip install geocoder
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 98 kB 6.8 MB/s
# ...

# %%
from geopy.geocoders import Nominatim
from geopy import distance

# %%
from geopy import geocoders
geocoders.Nominatim(user_agent="colab")

# %%
location1=
location2=
# Out:
#   File "<ipython-input-12-28e197940b74>", line 1
#     location1=
#               ^
# SyntaxError: invalid syntax
